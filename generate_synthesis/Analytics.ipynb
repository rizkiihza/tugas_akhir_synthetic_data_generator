# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("result.csv")
df.head()
# Out:
#    Unnamed: 0                                     config  \
# 0           0  k = 25, dslimit = 0.010000, sizeLimit = 2
# 1           1  k = 25, dslimit = 0.010000, sizeLimit = 2
# 2           2  k = 25, dslimit = 0.010000, sizeLimit = 2
# 3           3  k = 25, dslimit = 0.010000, sizeLimit = 2
# 4           4  k = 25, dslimit = 0.010000, sizeLimit = 2
#
#                     filename  Number of predicate  Accuracy  Time     Memory
# 0  generated_data/data_1.txt                   20  0.608696   109   10485592
# 1  generated_data/data_2.txt                   30  0.609756   166   17945192
# 2  generated_data/data_3.txt                   50  0.642857   294   84574080
# 3  generated_data/data_4.txt                  100  0.838710   794  155450568
# 4  generated_data/data_5.txt                   30  0.622222   147   13041688

# %%
sns.scatterplot(x='Number of predicate', y='Time', data=df)
plt.show()

# %%
sns.scatterplot(x='Number of predicate', y='Memory', data=df)
plt.show()

# %%
sns.scatterplot(x='Number of predicate', y='Accuracy', data=df)
plt.show()

# %%
sns.distplot(df['Accuracy'], hist=False)
plt.show()

# %%
sns.boxplot(df['Accuracy'])
plt.show()

# %%
df['Accuracy'].describe()
# Out:
# count    30.000000
# mean      0.694694
# std       0.086941
# min       0.514286
# 25%       0.634146
# 50%       0.684321
# 75%       0.770239
# max       0.891892
# Name: Accuracy, dtype: float64
