# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("result.csv")
df2 = pd.read_csv("result2.csv")

df2.head
df= pd.concat([df1, df2])
df
# Out:
#     No                                     config                    filename  \
# 0    0  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_1.txt
# 1    1  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_2.txt
# 2    2  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_3.txt
# 3    3  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_4.txt
# 4    4  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_5.txt
# 5    5  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_6.txt
# 6    6  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_7.txt
# 7    7  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_8.txt
# 8    8  k = 25, dslimit = 0.010000, sizeLimit = 2   generated_data/data_9.txt
# 9    9  k = 25, dslimit = 0.010000, sizeLimit = 2  generated_data/data_10.txt
# 10  10  k = 25, dslimit = 0.010000, sizeLimit = 2  generated_data/data_11.txt
# ...

# %%
sns.scatterplot(x='Number of predicate', y='Time', data=df)
plt.show()

# %%
sns.scatterplot(x='Number of predicate', y='Memory', data=df)
plt.show()

# %%
sns.scatterplot(x='Number of predicate', y='Accuracy', data=df)
plt.show()

# %%
sns.distplot(df['Accuracy'], hist=False)
plt.show()

# %%
sns.boxplot(df['Accuracy'])
plt.show()

# %%
df['Accuracy'].describe()
# Out:
# count    70.000000
# mean      0.703637
# std       0.087538
# min       0.487805
# 25%       0.641484
# 50%       0.694444
# 75%       0.764706
# max       0.928571
# Name: Accuracy, dtype: float64
